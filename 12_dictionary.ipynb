# %% [markdown]
# # Python Dictionaries
#     ```python
#
#     thisdict = {
#         "brand": "Ford",
#         "model": "Mustang",
#         "year": 1964
#     }
#
#     ```
# * Dictionaries are used to store data values in key:value pairs.
# * A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
# * Dictionaries are written with curly brackets, and have keys and values:
# * Dictionary items are presented in key:value pairs, and can be referred to by using the key name.
# * Dictionaries cannot have two items with the same key:

# %%
# Example 1 --> Creating a dictionary
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964 
}

thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
# Accessing dictionary items
thisdict["brand"]
# Out:
# 'Ford'

# %%
# Dictionaries cannot have two items with the same key:
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964,
    "year": 2000
}

thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2000}

# %% [markdown]
# ### Dictionary Length
# To determine how many items a dictionary has, use the len() function:

# %%
len(thisdict)
# Out:
# 3

# %% [markdown]
# ## Python - Access Dictionary Items
# * You can access the items of a dictionary by referring to its key name, inside square brackets:
# * There is also a method called get() that will give you the same result:

# %%
model = thisdict["model"]
model
# Out:
# 'Mustang'

# %%
# .get() method
thisdict.get("model")
# Out:
# 'Mustang'

# %% [markdown]
# ## Get Keys
# * The keys() method will return a list of all the keys in the dictionary.
# * The list of the keys is a view of the dictionary, meaning that any changes done to the dictionary will be reflected in the keys list.

# %%
keys = thisdict.keys()
keys
# Out:
# dict_keys(['brand', 'model', 'year'])

# %% [markdown]
# ## Get Values
# * The values() method will return a list of all the values in the dictionary.

# %%
thisdict.values()
# Out:
# dict_values(['Ford', 'Mustang', 2000])

# %% [markdown]
# ## Get Items
# * The items() method will return each item in a dictionary, as tuples in a list.

# %%
x = thisdict.items()
x
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 2000)])

# %% [markdown]
# ## Check if Key Exists
# * To determine if a specified key is present in a dictionary use the `in` keyword:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

if "model" in thisdict:
    print("Yes, 'model' is one of the keys in the thisdict")
# Out:
# Yes, 'model' is one of the keys in the thisdict

# %% [markdown]
# ## Change Values
# * You can change the value of a specific item by referring to its key name:

# %%
thisdict["year"] = 2018
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2018}

# %% [markdown]
# ### The update() method will update the dictionary with the items from the given argument.
#
# * The argument must be a dictionary, or an iterable object with key:value pairs.
# * The update method takes only one arguement
# * dict.update({"key":"value"})

# %%
thisdict.update({"brand": "Toyota"})
thisdict
# Out:
# {'brand': 'Toyota', 'model': 'Mustang', 'year': 2018}

# %% [markdown]
# ## Python - Add Dictionary Items
# * Adding an item to the dictionary is done by using a new index key and assigning a value to it:

# %%
thisdict["color"] = "Red"
thisdict
# Out:
# {'brand': 'Toyota', 'model': 'Mustang', 'year': 2018, 'color': 'Red'}

# %% [markdown]
# ### Update Dictionary
# * The update() method will update the dictionary with the items from a given argument. If the item does not exist, the item will be added.
# * The argument must be a dictionary, or an iterable object with key:value pairs.

# %%
thisdict.update({"fuel": "Diesel"})
thisdict
# Out:
# {'brand': 'Toyota',
#  'model': 'Mustang',
#  'year': 2018,
#  'color': 'Red',
#  'fuel': 'Diesel'}

# %% [markdown]
# ## Python - Remove Dictionary Items
# * There are several methods to remove items from a dictionary:

# %%
# The pop() method removes the item with the specified key name:
thisdict.pop("fuel")
# Out:
# 'Diesel'

# %%
thisdict
# Out:
# {'brand': 'Toyota', 'model': 'Mustang', 'year': 2018, 'color': 'Red'}

# %% [markdown]
# ### Example - The popitem() method removes the last inserted item (in versions before 3.7, a random item is removed instead):

# %%
thisdict.popitem()
# Out:
# ('color', 'Red')

# %%
thisdict
# Out:
# {'brand': 'Toyota', 'model': 'Mustang', 'year': 2018}

# %% [markdown]
# ### Example
# * The `del` keyword removes the item with the specified key name:
# * The del keyword can also delete the dictionary completely:

# %%
del thisdict["year"]

# %%
thisdict
# Out:
# {'brand': 'Toyota', 'model': 'Mustang'}

# %%
# Deleting the entire dictionary
del thisdict

# %%
thisdict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 thisdict
#
# NameError: name 'thisdict' is not defined

# %% [markdown]
# ### Example
# * The clear() method empties the dictionary:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict.clear()

# %%
thisdict
# Out:
# {}

# %% [markdown]
# ## Python - Loop Dictionaries
#
# * You can loop through a dictionary by using a for loop. When looping through a dictionary, the return value are the keys of the dictionary, but there are methods to return the values as well.

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
# This will return the keys only
for x in thisdict:
    print(x)
# Out:
# brand
# model
# year

# %%
# Print all values in the dictionary, one by one
for x in thisdict:
    print(thisdict[x])
# Out:
# Ford
# Mustang
# 1964

# %%
# You can also use the values() method to return values of a dictionary:

for x in thisdict.values():
    print(x)
# Out:
# Ford
# Mustang
# 1964

# %%
# You can use the keys() method to return the keys of a dictionary:

for x in thisdict.keys():
    print(x)
# Out:
# brand
# model
# year

# %%
# Loop through both keys and values, by using the items() method

for key,value in thisdict.items():
    print(key, value)
# Out:
# brand Ford
# model Mustang
# year 1964

# %% [markdown]
# ## Python - Copy Dictionaries
# * You cannot copy a dictionary simply by typing dict2 = dict1, because: dict2 will only be a reference to dict1, and changes made in dict1 will automatically also be made in dict2.
#
# There are ways to make a copy, one way is to use the built-in Dictionary method copy().

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

mydict = thisdict
mydict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict["color"] = "Red"
mydict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'Red'}

# %%
# Copyign without the original dict changes affecting the new dictionary
mydict = thisdict.copy()
mydict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'Red'}

# %%
thisdict.update({"fule_type": "Diesel"})
print(thisdict)
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'Red', 'fule_type': 'Diesel'}
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'Red'}

# %% [markdown]
# ### Another way to make a copy is to use the built-in function dict().

# %%
mydict = dict(thisdict)
mydict
# Out:
# {'brand': 'Ford',
#  'model': 'Mustang',
#  'year': 1964,
#  'color': 'Red',
#  'fule_type': 'Diesel'}

# %% [markdown]
# ## Python - Nested Dictionaries
# * A dictionary can contain dictionaries, this is called nested dictionaries.

# %%
my_family = {
    "husband": {
        "name": "Ibrahim",
        "age": "31"
    },
    "wife": {
        "name": "Samira",
        "age": 30
    },
    "son": {
        "name": "Haider",
        "age": "12W"
    }
}

my_family
# Out:
# {'husband': {'name': 'Ibrahim', 'age': '31'},
#  'wife': {'name': 'Samira', 'age': 30},
#  'son': {'name': 'Haider', 'age': '12W'}}

# %%
for member in my_family.values():
    for value in member.values():
        print(value)
# Out:
# Ibrahim
# 31
# Samira
# 30
# Haider
# 12W

# %%
# Create three dictionaries, then create one dictionary that will contain the other three dictionaries:

husband =  {
        "name": "Ibrahim",
        "age": "31"
    }

wife =  {
        "name": "Samira",
        "age": 30
    }

son = {
    "name": "Haider",
    "age": "12W"
}

myfamily = {
    "member1": husband,
    "member2": wife,
    "member3": son
}

myfamily
# Out:
# {'member1': {'name': 'Ibrahim', 'age': '31'},
#  'member2': {'name': 'Samira', 'age': 30},
#  'member3': {'name': 'Haider', 'age': '12W'}}

# %%
# Loop Through Nested Dictionaries
for member in myfamily.values():
    for key,value in member.items():
        print(f"{key}:{value}")
# Out:
# name:Ibrahim
# age:31
# name:Samira
# age:30
# name:Haider
# age:12W
